# %% [markdown]
# # Exercise 3.2

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 1) Create a random vector (1D array) which has 500 elements, and the element are drawn from a uniform distribution. Name this 1D array `uniform_arr`.

# %%
uniform_arr = np.random.rand(500)

# %%
uniform_arr.shape
# Out:
# (500,)

# %% [markdown]
# 2) Create a random vector (1D array) which has 500 elements, and the element are drawn from a normal distribution. Name this 1D array `normal_arr`.

# %%
normal_arr = np.random.randn(500)

# %% [markdown]
# 3) Create a histogram of `uniform array`.

# %%
plt.hist(uniform_arr);

# %% [markdown]
# 4) Creat a histogram of `normal_array`.

# %%
plt.hist(normal_arr);

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.hist(uniform_arr);
ax2.hist(normal_arr);

# %%
plt.hist(uniform_arr)
plt.hist(normal_arr, alpha=.5);

# %% [markdown]
# 5) Create the plots for the pictures I shared on Slack > data channel.

# %%
normal1 = np.random.randn(1500)
normal2 = np.random.randn(1500)

plt.scatter(normal1, normal2, color='.5');

# %%
plt.scatter(normal1[normal1 < 0], normal2[normal1 < 0], color='r')
plt.scatter(normal1[normal1 >= 0], normal2[normal1 >= 0], color='b')
